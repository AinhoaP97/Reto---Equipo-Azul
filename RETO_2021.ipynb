# %%
import pandas as pd

# %%
df_2021 = pd.read_csv('2021.xlsx - Sheet1.csv')

# %%
df_2021.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                      Nombre  \
# 0             0           1        IBERDROLA CLIENTES SOCIEDAD ANONIMA.
# 1             1           2                     PAN AMERICAN ENERGY SL.
# 2             2           3  IBERDROLA ENERGIA ESPAÑA SOCIEDAD ANONIMA.
# 3             3           4             ALVEAN SUGAR SOCIEDAD LIMITADA.
# 4             4           5                 IBERDROLA, SOCIEDAD ANONIMA
#
#   Código NIF Localidad Provincia    País  Código primario CNAE 2009  \
# 0  A95758389    BILBAO   Vizcaya  ESPANA                       3514
# 1  B88260203    BILBAO   Vizcaya  ESPANA                       6420
# 2  A95758371    BILBAO   Vizcaya  ESPANA                       4611
# 3  B95773057    BILBAO   Vizcaya  ESPANA                       4636
# 4  A48010615    BILBAO   Vizcaya  ESPANA                       6420
#
#                    Literal código CNAE 2009 primario   Fecha constitución  \
# ...

# %%
df_2021.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Nombre', 'Código NIF', 'Localidad',
#        'Provincia', 'País', 'Código primario CNAE 2009',
#        'Literal código CNAE 2009 primario', 'Fecha constitución',
#        'Importador / Exportador', 'Países importación', 'Países exportación',
#        'Otros activos líquidos\nmil EUR\n2021', 'Inmovilizado\nmil EUR\n2021',
#        'Inmovilizado inmaterial\nmil EUR\n2021',
#        'Inmovilizado material\nmil EUR\n2021',
#        'Otros activos fijos\nmil EUR\n2021',
#        'Activo circulante\nmil EUR\n2021', 'Existencias\nmil EUR\n2021',
#        'Deudores\nmil EUR\n2021', 'Tesorería\nmil EUR\n2021',
#        'Total activo\nmil EUR\n2021', 'Capital suscrito\nmil EUR\n2021',
#        'Otros fondos propios\nmil EUR\n2021', 'Pasivo fijo\nmil EUR\n2021',
#        'Acreedores a L. P.\nmil EUR\n2021',
#        'Otros pasivos fijos\nmil EUR\n2021', 'Pasivo líquido\nmil EUR\n2021',
#        'Deudas financieras\nmil EUR\n2021',
# ...

# %%
df_2021.shape
# Out:
# (40554, 55)

# %%
df_2021.dtypes
# Out:
# Unnamed: 0.1                                              int64
# Unnamed: 0                                                int64
# Nombre                                                   object
# Código NIF                                               object
# Localidad                                                object
# Provincia                                                object
# País                                                     object
# Código primario CNAE 2009                                 int64
# Literal código CNAE 2009 primario                        object
# Fecha constitución                                       object
# Importador / Exportador                                  object
# Países importación                                       object
# Países exportación                                       object
# Otros activos líquidos\nmil EUR\n2021                    object
# Inmovilizado\nmil EUR\n2021                              object
# ...

# %%
df_2021.isna().sum()
# Out:
# Unnamed: 0.1                                                 0
# Unnamed: 0                                                   0
# Nombre                                                       0
# Código NIF                                                   0
# Localidad                                                    2
# Provincia                                                    0
# País                                                         0
# Código primario CNAE 2009                                    0
# Literal código CNAE 2009 primario                            0
# Fecha constitución                                           6
# Importador / Exportador                                      0
# Países importación                                       37825
# Países exportación                                       39554
# Otros activos líquidos\nmil EUR\n2021                        0
# Inmovilizado\nmil EUR\n2021                                  0
# ...

# %%
df_2021.eq(0).sum()
# Out:
# Unnamed: 0.1                                             4
# Unnamed: 0                                               0
# Nombre                                                   0
# Código NIF                                               0
# Localidad                                                0
# Provincia                                                0
# País                                                     0
# Código primario CNAE 2009                                0
# Literal código CNAE 2009 primario                        0
# Fecha constitución                                       0
# Importador / Exportador                                  0
# Países importación                                       0
# Países exportación                                       0
# Otros activos líquidos\nmil EUR\n2021                    0
# Inmovilizado\nmil EUR\n2021                              0
# Inmovilizado inmaterial\nmil EUR\n2021                   0
# ...

# %%
df_2021.eq('n.d.').sum()
# Out:
# Unnamed: 0.1                                                 0
# Unnamed: 0                                                   0
# Nombre                                                       0
# Código NIF                                                   0
# Localidad                                                    0
# Provincia                                                    0
# País                                                         0
# Código primario CNAE 2009                                    0
# Literal código CNAE 2009 primario                            0
# Fecha constitución                                           0
# Importador / Exportador                                      0
# Países importación                                           0
# Países exportación                                           0
# Otros activos líquidos\nmil EUR\n2021                     6406
# Inmovilizado\nmil EUR\n2021                               8296
# ...
